# %% [markdown]
# - Project Structure done
# - Environment Setup done
# - Load the Dataset (first real step) done.

# %%
import pandas as pd

df = pd.read_csv("data/shopping_trends.csv")

print(df.shape)
print(df.columns)
# Out:
# (3900, 19)
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='str')

# %% [markdown]
# - Coulmn Understanding
#
#
# | Column | Type | What it represents | Why it matters |
# | ------ | ---- | ------------------ | -------------- |
# | Customer ID | Integer | ID of each customer | shows each customer as a unique identity |
# | Age | Integer | Age of Customer | Mapping out according to Generation |
# | Gender | String | Gender of Customer | Differences/Similarities between purchase due to Gender |
# | Item Purchased | String | Item Purchased | Best Selling, Least Selling |
# | Category | String | Clothing/Footwear/Accessory | Demand |
# | Purchase Amount | Integer | Money Spent | How much are people willing to spend |
# | Location | String | Location | What's popular in which area? |
# | Size | String | Size of people's clothes | Demand |
# | Color | String | Color of clothes | Popularity & Demand |
# | Season | String | Warm / Cool Clothes | Demand according to Season |
# | Review Rating | Float | Rating | Feedback |
# | Subscription Status | Boolean | Loyalty | Do they wanna shop again? |
# | Payment Method | String | Digital/Credit/Cash | Which service do people use? |
# | Preferred Payment Method | String | Digital/Credit/Cash | Which service do people prefer? |
# | Shipping Type | String | Urgency | Are they willing to spend more for quickness? |
# | Discount Applied | Boolean | Money Spent | What other offers should be made? |
# | Promo Code Used | Boolean | Money Spent | What other offers should be made? |
# | Previous Purchases | Integer | Purchases Made | How much do they like the store? |
# | Frequency of Purchases | String | Frequency | How frequently will they spend money? |

# %% [markdown]
# - Data Check done
# - First-Level Observations
#     - Avg Rating is 3.75
#     - Avg Previous Purchases is 25.35
#     - Most commonly occuring Age is 69
# - First Visualization (only 1–2) done. Charts in Excel itself
#
#
# Does one row = one purchase OR one customer? Can a customer appear multiple times?
# 1 row = 1 customer cuz no 2 rows have same customer ID
#
# - Check missing values: None
# - Fix obvious issues: done
# - Group data by customer:

# %%
df.groupby("Customer ID")

# %% [markdown]
# - What defines a “valuable customer”?
#
#     Subscription Status, Frequency of Purchases, Purchase Amount, Previous Purchases
# - Create a new DataFrame

# %%
import pandas as pd

data = {"customer_id": [], "total_spent": [], 
    "purchase_count": [], "avg_spent": []}
#load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
# Empty DataFrame
# Columns: [customer_id, total_spent, purchase_count, avg_spent]
# Index: []

# %% [markdown]
# - Insights
#     - Who are your top 10% customers?
#         Subscribed, Purchase Weekly/Bi-Weekly/Fortnightly, Purchase Amount >= 25, Previous Purchases >= 5
#     - Are there customers who buy frequently but spend less?
#         111 customers spend < 25 but Spend bi-weekly/weekly/fortnightly
#     - Are there high spenders but low frequency?
#         1144 customers spend above average but monthly/3 months/quarterly/annually
#
# - Visualization
# Top customers by total spend
